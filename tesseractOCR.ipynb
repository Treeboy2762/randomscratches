# %% [markdown]
# <a href="https://colab.research.google.com/github/Treeboy2762/randomscratches/blob/main/tesseractOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 3s (1,786 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !which tesseract
# Out:
# /usr/bin/tesseract

# %%
# !sudo apt-get install tesseract-ocr-kor
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr-kor is already the newest version (4.00~git24-0e00fe6-1.2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
import pytesseract
from PIL import Image
print(pytesseract.image_to_string(Image.open('Original0.png'), lang='Hangul'))
# Out:
# ---------------------------------------------------------------------------
# TesseractError                            Traceback (most recent call last)
# <ipython-input-6-afa9a1fc66e5> in <module>()
#       1 import pytesseract
#       2 from PIL import Image
# ----> 3 print(pytesseract.image_to_string(Image.open('Original0.png'), lang='Hangul'))
#       4
#
# /usr/local/lib/python3.7/dist-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     415         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     416         Output.STRING: lambda: run_and_get_output(*args),
# --> 417     }[output_type]()
#     418
#     419
#
# /usr/local/lib/python3.7/dist-packages/pytesseract/pytesseract.py in <lambda>()
#     414         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     415         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# ...

# %%
# !sudo apt install tesseract-ocr tesseract-ocr-script-hang tesseract-ocr-script-hang-vert
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following NEW packages will be installed:
#   tesseract-ocr-script-hang tesseract-ocr-script-hang-vert
# 0 upgraded, 2 newly installed, 0 to remove and 39 not upgraded.
# Need to get 3,614 kB of archives.
# After this operation, 9,601 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-script-hang all 4.00~git24-0e00fe6-1.2 [1,854 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-script-hang-vert all 4.00~git24-0e00fe6-1.2 [1,761 kB]
# Fetched 3,614 kB in 6s (652 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# ...

# %%
import pytesseract
import cv2
import os
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
#이미지를 불러와 gray 스케일로 변환해 준다.

image = cv2.imread('Original1.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

#pytesseract에서는 numpy array를 읽지 못하고 file을 읽기 때문에 os로 파일을 불러들여야 한다.
filename = "test.png".format(os.getpid())
cv2.imwrite(filename, gray)

#pytesseract의 image to string을 써준다. 
#숫자니까 lang = 'None'으로

text = pytesseract.image_to_string(Image.open(filename), lang = 'Hangul')
os.remove(filename)

#결과를 보자.

print(text)
cv2_imshow(image)
# Out:
# — 콘크리트 : 도 신 게 빈
# (3) 콘크리트 : f66=40MPa( 두 부 보 , 기 둥 )
# 재 료
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 그 ㆍ 조라 ~ 버 , -
# 제 2 공 구 : 중랑 ~ 별 내 리트 : f=27Ma( 기 초 )
#
# 구 리 ~ 포 천 고속도로 실 시 설계 교 각 배
# (
#
#
#
# 철 근 상 세
#
# 철 근 고 임 대 (Bar supp 아 t) 및
#
# t+ 가 | / 간 격 재 (spacer) 상 세 도
#
# ———— . ‘ ; (~ woe S=NONE
# 철근 재 료
#
#
#
#
#
#
#
# (2) H22 =6.300 N=32 (2) H32 =19.744 \=48 기둥 덮 개 용 가 격 ×
# H1i9 = = 1=340 a=18.710 b=534 C=500 (SD40) ( 전 체 분) [동 가 용 간 격 재
# a=1.151 b=2.637 C=460 si 기“ xa lPcaoos hoc cco 5
# (3s) (var.) ~1.530 (2) 끈 오 이 을 | ㅜ _ ㅜ 3 총 은 | 다 Bo | 그
# H25 - 09 H32 19 744 48 : :
# = 는 (6) 119 2 en 노군 1 H32 11.242 10 112.420 (kaf/m) ADD 6%
# =8 8 N= r=: a= . = C=!
# a=1.151 b=2.950 C=460 2 7.000 oop
# (var.) ~2.651 = - ~
# (24) 1400 7 800 ~ 3 oo
# H19 7 nas ) 04 TL
# a=1.151 b=2.936 c=460 기
# a) (var) 1.691 c5 |
# P” TL
# f p2 TL
# H19 8 < ,
# =1.7 == +t 가 6.230 14.646 18.525 3
# 르 B5 H29 12.680 27 342.360 이 o
# ~\
# 기 a Aan nan 1 7 fa
# om mm ™ 2 (3) 10 mm ” 조기 7 ee [eo EE |
# ...
